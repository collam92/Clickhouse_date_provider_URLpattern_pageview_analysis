# %%
import pandas as pd
# дать ссылку на таблицу с землей
zem= pd.read_excel('/content/searchresult_1.1 (37).xls', header=1)
zem.columns=[i.strip() for i in zem.columns]
# дать ссылку на таблицу с зданиями
zdan=pd.read_excel('/content/searchresult_1.2 (48).xls', header=1)
zdan.columns.values[15]='Удалить'
zdan.columns.values[17]='Площадь'
zdan.columns=[i.strip() for i in zdan.columns]
# дать ссылку на таблицу с помещениями
pom=pd.read_excel('/content/searchresult_1.3 (46).xls', header=1)
pom.columns=[i.strip() for i in pom.columns]

# обработка таблицы с землей
del zem['Площадь']
zem=zem.rename(columns={'Площадь, кв.м.':'Площадь'})
zem['Наименование объекта учёта']='Земельный участок'
zem['Вид объекта']='Земельный участок'
zem['Назначение объекта']='Земельный участок'
zem['Техническое состояние']='У земельных участков отсутвует поле техническое состояние'
zem['Единица измерения']='Квадратный метр (ЗУ)'
zem['Этажность']='У земельных участков отсутвует поле этажности'
zem['Подземная этажность']='У земельных участков отсутвует поле подземной этажности'
zem['Год ввода в эксплуатацию']='У земельных участков отсутвует поле года ввода в эксплуатацию'
zem['Остаточная стоимость, руб']='У земельных участков отсутвует поле остаточной стоимости'
zem['Дата остаточной стоимости']='У земельных участков отсутвует поле остаточной стоимости'
columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес',
                 'Наименование объекта учёта','Вид объекта','Назначение объекта','Фактическое использование',
                 'Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
                 'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб',
                 'Первоначальная стоимость, дата','Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб',
                 'Балансовая стоимость, дата', 'Оценочная стоимость в руб', 'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта',
                 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
zem['Категория целевого использования']=zem['Категория целевого использования'].astype(str)
zem=zem[columns_to_keep]
zem.to_excel('Земля.xlsx', index=False )

# обработка таблицы со зданиями
zdan=zdan.rename(columns={'Наименование объекта учета':'Наименование объекта учёта','Единица измерения в':'Единица измерения',
                          'Первоначальная стоимость, руб':'Первоначальная стоимость в руб','Дата первоначальной стоимости':'Первоначальная стоимость, дата',
                          'Балансовая стоимость, руб':'Балансовая стоимость в руб','Дата балансовой стоимости':'Балансовая стоимость, дата',
                          'Оценочная стоимость, руб':'Оценочная стоимость в руб', 'Валюта оценочной стоимости':'Оценочная стоимость, валюта',
                          'Курс оценочной стоимости':'Оценочная стоимость, курс', 'Дата оценочной стоимости':'Оценочная стоимость, дата'})
columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес','Наименование объекта учёта','Вид объекта','Назначение объекта',
                 'Фактическое использование','Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
                 'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб','Первоначальная стоимость, дата',
                 'Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб','Балансовая стоимость, дата', 'Оценочная стоимость в руб',
                 'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта', 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
zdan=zdan[columns_to_keep]
zdan.to_excel('Здания.xlsx', index=False )

# обработка таблицы с помещениями
pom=pom.rename(columns={'Наименование объекта учета':'Наименование объекта учёта','Значение.1':'Площадь','Единица измерения в':'Единица измерения',
                        'Первоначальная стоимость, руб':'Первоначальная стоимость в руб','Дата первоначальной стоимости':'Первоначальная стоимость, дата',
                        'Балансовая стоимость, руб':'Балансовая стоимость в руб','Дата балансовой стоимости':'Балансовая стоимость, дата',
                        'Оценочная стоимость, руб':'Оценочная стоимость в руб', 'Валюта оценочной стоимости':'Оценочная стоимость, валюта',
                        'Курс оценочной стоимости':'Оценочная стоимость, курс', 'Дата оценочной стоимости':'Оценочная стоимость, дата'})
pom['Этажность']='У помещений отсутствует поле этажности'
pom['Подземная этажность']='У помещений отсутствует поле подземной этажности'
pom['Год ввода в эксплуатацию']='У помещений отсутствует поле года ввода в эксплуатацию'
columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес','Наименование объекта учёта','Вид объекта','Назначение объекта',
                 'Фактическое использование','Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
                 'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб','Первоначальная стоимость, дата',
                 'Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб','Балансовая стоимость, дата', 'Оценочная стоимость в руб',
                 'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта', 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
pom=pom[columns_to_keep]
pom.to_excel('Помещения.xlsx', index=False)

# свод таблиц в одну
df=pd.concat([zem,zdan,pom],ignore_index=True).sort_values(by=['Страна','Город','Адрес','Наименование объекта учёта'])
df.to_excel('Свод.xlsx', index=False )

# %%
# import pandas as pd
# # дать ссылку на таблицу с землей
# zem= pd.read_excel('/content/searchresult_1.1 (33).xls')
# zem.columns=[i.strip() for i in zem.columns]
# # дать ссылку на таблицу с зданиями
# zdan=pd.read_excel('/content/searchresult_1.2 (44).xls')
# zdan.columns=[i.strip() for i in zdan.columns]
# # дать ссылку на таблицу с помещениями
# pom=pd.read_excel('/content/searchresult_1.3 (42).xls')
# pom.columns=[i.strip() for i in pom.columns]

# # обработка таблицы с землей
# zem['Наименование объекта учёта']='Земельный участок'
# zem['Площадь, кв.м.'] = zem['Площадь']
# zem['Вид объекта']='Земельный участок'
# zem['Назначение объекта']='Земельный участок'
# zem['Техническое состояние']='У земельных участков отсутвует поле техническое состояние'
# zem['Единица измерения']='Квадратный метр (ЗУ)'
# zem['Этажность']='У земельных участков отсутвует поле этажности'
# zem['Подземная этажность']='У земельных участков отсутвует поле подземной этажности'
# zem['Год ввода в эксплуатацию']='У земельных участков отсутвует поле года ввода в эксплуатацию'
# zem['Остаточная стоимость, руб']='У земельных участков отсутвует поле остаточной стоимости'
# zem['Дата остаточной стоимости']='У земельных участков отсутвует поле остаточной стоимости'
# columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес',
#                  'Наименование объекта учёта','Вид объекта','Назначение объекта','Фактическое использование',
#                  'Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
#                  'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб',
#                  'Первоначальная стоимость, дата','Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб',
#                  'Балансовая стоимость, дата', 'Оценочная стоимость в руб', 'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта',
#                  'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
# zem['Категория целевого использования']=zem['Категория целевого использования'].astype(str)
# zem=zem[columns_to_keep]
# zem.to_excel('Земля.xlsx', index=False )

# # обработка таблицы со зданиями
# zdan=zdan.rename(columns={'Наименование объекта учета':'Наименование объекта учёта','Значение.1':'Площадь','Единица измерения в':'Единица измерения',
#                           'Первоначальная стоимость, руб':'Первоначальная стоимость в руб','Дата первоначальной стоимости':'Первоначальная стоимость, дата',
#                           'Балансовая стоимость, руб':'Балансовая стоимость в руб','Дата балансовой стоимости':'Балансовая стоимость, дата',
#                           'Оценочная стоимость, руб':'Оценочная стоимость в руб', 'Валюта оценочной стоимости':'Оценочная стоимость, валюта',
#                           'Курс оценочной стоимости':'Оценочная стоимость, курс', 'Дата оценочной стоимости':'Оценочная стоимость, дата'})
# columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес','Наименование объекта учёта','Вид объекта','Назначение объекта',
#                  'Фактическое использование','Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
#                  'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб','Первоначальная стоимость, дата',
#                  'Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб','Балансовая стоимость, дата', 'Оценочная стоимость в руб',
#                  'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта', 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
# zdan=zdan[columns_to_keep]
# zdan.to_excel('Здания.xlsx', index=False )

# # обработка таблицы с помещениями
# pom=pom.rename(columns={'Наименование объекта учета':'Наименование объекта учёта','Значение.1':'Площадь','Единица измерения в':'Единица измерения',
#                         'Первоначальная стоимость, руб':'Первоначальная стоимость в руб','Дата первоначальной стоимости':'Первоначальная стоимость, дата',
#                         'Балансовая стоимость, руб':'Балансовая стоимость в руб','Дата балансовой стоимости':'Балансовая стоимость, дата',
#                         'Оценочная стоимость, руб':'Оценочная стоимость в руб', 'Валюта оценочной стоимости':'Оценочная стоимость, валюта',
#                         'Курс оценочной стоимости':'Оценочная стоимость, курс', 'Дата оценочной стоимости':'Оценочная стоимость, дата'})
# pom['Этажность']='У помещений отсутствует поле этажности'
# pom['Подземная этажность']='У помещений отсутствует поле подземной этажности'
# pom['Год ввода в эксплуатацию']='У помещений отсутствует поле года ввода в эксплуатацию'
# columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес','Наименование объекта учёта','Вид объекта','Назначение объекта',
#                  'Фактическое использование','Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
#                  'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб','Первоначальная стоимость, дата',
#                  'Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб','Балансовая стоимость, дата', 'Оценочная стоимость в руб',
#                  'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта', 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
# pom=pom[columns_to_keep]
# pom.to_excel('Помещения.xlsx', index=False )

# # свод таблиц в одну
# df=pd.concat([zem,zdan,pom],ignore_index=True).sort_values(by=['Страна','Город','Адрес','Наименование объекта учёта'])
# df.to_excel('Свод.xlsx', index=False )

# %%
# import pandas as pd
# # дать ссылку на таблицу с землей
# zem= pd.read_excel('/content/searchresult_1.1 (34).xls')
# zem.columns=[i.strip() for i in zem.columns]
# zem['Наименование объекта учёта']='Земельный участок'
# zem['Площадь, кв.м.']=zem['Площадь']
# zem['Вид объекта']='Земельный участок'
# zem['Назначение объекта']='Земельный участок'
# zem['Техническое состояние']='У земельных участков отсутвует поле техническое состояние'
# zem['Единица измерения']='Квадратный метр (ЗУ)'
# zem['Этажность']='У земельных участков отсутвует поле этажности'
# zem['Подземная этажность']='У земельных участков отсутвует поле подземной этажности'
# zem['Год ввода в эксплуатацию']='У земельных участков отсутвует поле года ввода в эксплуатацию'
# zem['Остаточная стоимость, руб']='У земельных участков отсутвует поле остаточной стоимости'
# zem['Дата остаточной стоимости']='У земельных участков отсутвует поле остаточной стоимости'
# columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес',
#                  'Наименование объекта учёта','Вид объекта','Назначение объекта','Фактическое использование',
#                  'Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
#                  'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб',
#                  'Первоначальная стоимость, дата','Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб',
#                  'Балансовая стоимость, дата', 'Оценочная стоимость в руб', 'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта',
#                  'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
# zem=zem[columns_to_keep]
# zem['Категория целевого использования']=zem['Категория целевого использования'].astype(str)
# zem.to_excel('Земля.xlsx', index=False )

# %%
# # дать ссылку на таблицу с объектами
# zdan=pd.read_excel('/content/searchresult_1.2 (45).xls')
# zdan.columns=[i.strip() for i in zdan.columns]

# zdan.head()
# zdan=zdan.rename(columns={'Наименование объекта учета':'Наименование объекта учёта','Значение.1':'Площадь','Единица измерения в':'Единица измерения',
#                           'Первоначальная стоимость, руб':'Первоначальная стоимость в руб','Дата первоначальной стоимости':'Первоначальная стоимость, дата',
#                           'Балансовая стоимость, руб':'Балансовая стоимость в руб','Дата балансовой стоимости':'Балансовая стоимость, дата',
#                           'Оценочная стоимость, руб':'Оценочная стоимость в руб', 'Валюта оценочной стоимости':'Оценочная стоимость, валюта',
#                           'Курс оценочной стоимости':'Оценочная стоимость, курс', 'Дата оценочной стоимости':'Оценочная стоимость, дата'})
# columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес','Наименование объекта учёта','Вид объекта','Назначение объекта',
#                  'Фактическое использование','Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
#                  'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб','Первоначальная стоимость, дата',
#                  'Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб','Балансовая стоимость, дата', 'Оценочная стоимость в руб',
#                  'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта', 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
# zdan=zdan[columns_to_keep]
# zdan.head()
# zdan.to_excel('Здания.xlsx', index=False )
# # zdan.columns.values.tolist ()

# %%
# pom=pd.read_excel('/content/searchresult_1.3 (43).xls')
# pom.columns=[i.strip() for i in pom.columns]
# pom=pom.rename(columns={'Наименование объекта учета':'Наименование объекта учёта','Значение.1':'Площадь','Единица измерения в':'Единица измерения',
#                         'Первоначальная стоимость, руб':'Первоначальная стоимость в руб','Дата первоначальной стоимости':'Первоначальная стоимость, дата',
#                         'Балансовая стоимость, руб':'Балансовая стоимость в руб','Дата балансовой стоимости':'Балансовая стоимость, дата',
#                         'Оценочная стоимость, руб':'Оценочная стоимость в руб', 'Валюта оценочной стоимости':'Оценочная стоимость, валюта',
#                         'Курс оценочной стоимости':'Оценочная стоимость, курс', 'Дата оценочной стоимости':'Оценочная стоимость, дата'})
# pom['Этажность']='У помещений отсутствует поле этажности'
# pom['Подземная этажность']='У помещений отсутствует поле подземной этажности'
# pom['Год ввода в эксплуатацию']='У помещений отсутствует поле года ввода в эксплуатацию'
# columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес','Наименование объекта учёта','Вид объекта','Назначение объекта',
#                  'Фактическое использование','Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
#                  'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб','Первоначальная стоимость, дата',
#                  'Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб','Балансовая стоимость, дата', 'Оценочная стоимость в руб',
#                  'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта', 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
# pom=pom[columns_to_keep]
# pom.to_excel('Помещения.xlsx', index=False )

# %%
# df=pd.concat([zem,zdan,pom],ignore_index=True).sort_values(by=['Страна','Город','Адрес','Наименование'])
# df.to_excel('Свод.xlsx', index=False )

# %%
# import pandas as pd
# # дать ссылку на таблицу с зданиями
# zdan=pd.read_excel('/content/searchresult_1.2 (45).xls',header=1)
# zdan.columns.values[15]='Удалить'
# zdan.columns.values[17]='Площадь'
# zdan.columns=[i.strip() for i in zdan.columns]
# zdan=zdan.rename(columns={'Наименование объекта учета':'Наименование объекта учёта','Единица измерения в':'Единица измерения',
#                           'Первоначальная стоимость, руб':'Первоначальная стоимость в руб','Дата первоначальной стоимости':'Первоначальная стоимость, дата',
#                           'Балансовая стоимость, руб':'Балансовая стоимость в руб','Дата балансовой стоимости':'Балансовая стоимость, дата',
#                           'Оценочная стоимость, руб':'Оценочная стоимость в руб', 'Валюта оценочной стоимости':'Оценочная стоимость, валюта',
#                           'Курс оценочной стоимости':'Оценочная стоимость, курс', 'Дата оценочной стоимости':'Оценочная стоимость, дата'})
# columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес','Наименование объекта учёта','Вид объекта','Назначение объекта',
#                  'Фактическое использование','Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
#                  'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб','Первоначальная стоимость, дата',
#                  'Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб','Балансовая стоимость, дата', 'Оценочная стоимость в руб',
#                  'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта', 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
# zdan=zdan[columns_to_keep]
# zdan.to_excel('Здания.xlsx', index=False )

# %%
# import pandas as pd
# pom=pd.read_excel('/content/searchresult_1.3 (43).xls', header=1)
# pom.columns=[i.strip() for i in pom.columns]
# pom=pom.rename(columns={'Наименование объекта учета':'Наименование объекта учёта','Значение.1':'Площадь','Единица измерения в':'Единица измерения',
#                         'Первоначальная стоимость, руб':'Первоначальная стоимость в руб','Дата первоначальной стоимости':'Первоначальная стоимость, дата',
#                         'Балансовая стоимость, руб':'Балансовая стоимость в руб','Дата балансовой стоимости':'Балансовая стоимость, дата',
#                         'Оценочная стоимость, руб':'Оценочная стоимость в руб', 'Валюта оценочной стоимости':'Оценочная стоимость, валюта',
#                         'Курс оценочной стоимости':'Оценочная стоимость, курс', 'Дата оценочной стоимости':'Оценочная стоимость, дата'})
# pom['Этажность']='У помещений отсутствует поле этажности'
# pom['Подземная этажность']='У помещений отсутствует поле подземной этажности'
# pom['Год ввода в эксплуатацию']='У помещений отсутствует поле года ввода в эксплуатацию'
# columns_to_keep=['РНЗС','Дата РНЗС','Инвентарный номер','Страна', 'Город', 'Адрес','Наименование объекта учёта','Вид объекта','Назначение объекта',
#                  'Фактическое использование','Техническое состояние','Площадь','Единица измерения','Этажность','Подземная этажность','Год ввода в эксплуатацию',
#                  'Категория целевого использования', 'Регистрация права собственности плановая дата', 'Первоначальная стоимость в руб','Первоначальная стоимость, дата',
#                  'Остаточная стоимость, руб','Дата остаточной стоимости','Балансовая стоимость в руб','Балансовая стоимость, дата', 'Оценочная стоимость в руб',
#                  'Оценочная стоимость в валюте', 'Оценочная стоимость, валюта', 'Оценочная стоимость, курс', 'Оценочная стоимость, дата']
# pom=pom[columns_to_keep]
# pom.to_excel('Помещения.xlsx', index=False)
